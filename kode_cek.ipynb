# %% [markdown]
# # CEK PERBANDINGAN ANTARA IMAGE GRAYSCALE DAN MEDIAN 3X3

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(img_grey[0], cmap='gray')
plt.title("Original")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(img_median[0], cmap='gray')
plt.title("Median 3x3")
plt.axis('off')

plt.show()

# %% [markdown]
# # CEK PERBANDINGAN UKURAN PADA CITRA GRAYSCALE APAKAH SUDAH SAMA ATAU BELUM

# %%
outputnya menjadi:
img_grey = []
for img in images:
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    img_grey.append(gray)
img_grey = np.array(img_grey)
print("Shape grayscale:", img_grey.shape)

sizes = set()
for img in img_grey:
    sizes.add(img.shape)

print("Ukuran unik grayscale:", sizes)

show_sample_images(img_grey, labels, class_names)

# %% [markdown]
# # CEK PERBANDINGAN UKURAN PADA CITRA SEBELUM GRAYSCALE APAKAH SUDAH SAMA ATAU BELUM

# %%
print("Shape dataset:", images.shape)

sizes = set()
for img in images:
    sizes.add(img.shape)

print("Ukuran unik setelah resize:", sizes)
